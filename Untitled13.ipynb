# %% [markdown]
# <a href="https://colab.research.google.com/github/Dikshya5058/AI-and-ML/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 7 To-Do-Task
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
    (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
    (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
    (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
    (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
    (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]
# Task1:
low = []
moderate = []
high = []

for day in time_data:
    study = day[0]
    if study < 3:
        low.append(study)
    elif study <= 5:
        moderate.append(study)
    else:
        high.append(study)

print("Low study hours:", low)
print("Moderate study hours:", moderate)
print("High study hours:", high)
# Out:
# Low Study Hours: [2.5, 1.5, 2.0, 2.5]
# Moderate Study Hours: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High Study Hours: [5.5, 6.0]

# %%
# Task2:
print("Days with low study:", len(low))
print("Days with moderate study:", len(moderate))
print("Days with high study:", len(high))

# %%
# Task3:
study_minutes = []
for day in time_data:
    study_minutes.append(day[0]*60)

print("Study hours in minutes:", study_minutes)

# %%
# Task4:
total_study = 0
total_entertainment = 0
total_sleep = 0

for day in time_data:
    total_study += day[0]
    total_entertainment += day[1]
    total_sleep += day[2]

avg_study = total_study / len(time_data)
avg_entertainment = total_entertainment / len(time_data)
avg_sleep = total_sleep / len(time_data)

print("Average study hours:", round(avg_study,2))
print("Average entertainment hours:", round(avg_entertainment,2))
print("Average sleep hours:", round(avg_sleep,2))

# %%
# Task5:
import matplotlib.pyplot as plt

study_hours = [day[0] for day in time_data]
sleep_hours = [day[2] for day in time_data]

plt.scatter(study_hours, sleep_hours)
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study vs Sleep")
plt.show()
